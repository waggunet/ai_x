# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# # 1.import & 한글설정 & 경고메시지 ignore
# - 필요한 라이브러리를 로드하고 시각화에서 디스플레이를 선명하게 표시되도록 하고, 한글 폰트가 나오도록 설정하고 확인한다. 한글깨짐 여부를 그래프로 test

# %%
# 패키지 import
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# 시각화의 선명도를 높임
# %config InlineBackend.figure_format = "retina"

# seaborn 스타이 설정
sns.set(style='white', rc={'figure.figsize':(20,5)})

# 한글설정
plt.rc('font', family='Malgun Gothic') # 윈도우즈
plt.rc('axes', unicode_minus=False) # 축의 - 깨짐 방지

# 다른 폰트를 기본으로 하려면
import matplotlib.font_manager as fm
font_file = 'C:/Windows/Fonts/Hancom Gothic Regular.ttf'
font_name = fm.FontProperties(fname=font_file,
#                              size=10
                             ).get_name()
plt.rc('font', family=font_name)

# warning(경고) 안보이게
import warnings
# warnings.filterwarnings(action='default') #경고 메시지를 항상 표시 기본값
warnings.filterwarnings(action='ignore') # 경고 메시지 무시

# %% [markdown]
# # 2. 서울과 부산데이터만 df 변수
# - https://www.data.go.kr에서 “상가(상권)정보”를 다운 받아, 서울과 부산데이터만 df 변수에 읽어들인다.

# %%
# %ls "C:\ai_x\download\shareData\상가정보_250331/"
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 3664-591E
#
#  C:\ai_x\download\shareData\상가정보_250331 디렉터리
#
# 2025-05-02  오후 06:02    <DIR>          .
# 2025-05-02  오후 06:02    <DIR>          ..
# 2025-04-27  오후 11:07             1,011 [필독]파일열람방법.txt
# 2025-04-27  오후 11:07        61,227,944 소상공인시장진흥공단_상가(상권)정보_강원_202503.csv
# 2025-04-27  오후 11:07       356,572,082 소상공인시장진흥공단_상가(상권)정보_경기_202503.csv
# 2025-04-27  오후 11:07        93,472,559 소상공인시장진흥공단_상가(상권)정보_경남_202503.csv
# 2025-04-27  오후 11:07        76,425,275 소상공인시장진흥공단_상가(상권)정보_경북_202503.csv
# 2025-04-27  오후 11:07        40,070,868 소상공인시장진흥공단_상가(상권)정보_광주_202503.csv
# 2025-04-27  오후 11:07        61,715,005 소상공인시장진흥공단_상가(상권)정보_대구_202503.csv
# 2025-04-27  오후 11:07        41,491,092 소상공인시장진흥공단_상가(상권)정보_대전_202503.csv
# 2025-04-27  오후 11:07        84,550,600 소상공인시장진흥공단_상가(상권)정보_부산_202503.csv
# 2025-04-27  오후 11:07       294,549,483 소상공인시장진흥공단_상가(상권)정보_서울_202503.csv
# 2025-04-27  오후 11:07         9,303,432 소상공인시장진흥공단_상가(상권)정보_세종_202503.csv
# 2025-04-27  오후 11:07        28,457,489 소상공인시장진흥공단_상가(상권)정보_울산_202503.csv
# 2025-04-27  오후 11:07        73,022,149 소상공인시장진흥공단_상가(상권)정보_인천_202503.csv
# 2025-04-27  오후 11:07        52,997,974 소상공인시장진흥공단_상가(상권)정보_전남_202503.csv
# 2025-04-27  오후 11:07        56,252,705 소상공인시장진흥공단_상가(상권)정보_전북_202503.csv
# 2025-04-27  오후 11:07        32,943,677 소상공인시장진흥공단_상가(상권)정보_제주_202503.csv
# 2025-04-27  오후 11:07        66,591,896 소상공인시장진흥공단_상가(상권)정보_충남_202503.csv
# 2025-04-27  오후 11:07        50,727,673 소상공인시장진흥공단_상가(상권)정보_충북_202503.csv
#               18개 파일       1,480,372,914 바이트
#                2개 디렉터리  153,111,019,520 바이트 남음

# %%
# 서울 소상공인 데이터
df_seoul = pd.read_csv('C:/ai_x/download/shareData/상가정보_250331/소상공인시장진흥공단_상가(상권)정보_서울_202503.csv',
#                       encoding='utf-8',
#                       sep=',',
#                       low_memory=False
                      )
df_seoul.shape
# Out:
# (540517, 39)

# %%
# 부산 소상공인 데이터
df_busan = pd.read_csv('C:/ai_x/download/shareData/상가정보_250331/소상공인시장진흥공단_상가(상권)정보_부산_202503.csv',
#                       encoding='utf-8',
#                       sep=',',
#                       low_memory=False
                      )
df_busan.shape
# Out:
# (155537, 39)

# %%
df_seoul.columns == df_busan.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df = pd.concat( [df_seoul, df_busan])
df.shape
# Out:
# (696054, 39)

# %%
df.loc[0,['상호명','상권업종대분류명']]
# Out:
#         상호명 상권업종대분류명
# 0  부동산임대김은숙       음식
# 0    경희윤한의원     보건의료

# %%
df.reset_index(drop=True, inplace=True)
df.loc[0,['상호명','상권업종대분류명']]
# Out:
# 상호명         부동산임대김은숙
# 상권업종대분류명          음식
# Name: 0, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=696054, step=1)

# %%
# 현재 주피터노틈북이 쓰고 있는 메모리 용량
# pip install memory_profiler

# %%
# %load_ext memory_profiler
# %memit
# Out:
# peak memory: 958.29 MiB, increment: 0.08 MiB

# %%
del df_seoul, df_busan

# %%
# %load_ext memory_profiler
# %memit
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler
# peak memory: 745.89 MiB, increment: 0.00 MiB

# %% [markdown]
# # 3. df 데이터 셋의 결측치 확인 및 시각화
# - missingno 라이브러리 : https://github.com/ResidentMario/missingno (소스사이트)
# - matplotlib
# ## (0) missingno 라이브러리로 결측치 시각화
# - pip install missingno

# %%
import missingno as msno
msno.matrix(df) # 결측치가 없는 부분은 검정색, 결측치 부분은 하얀색
# Out:
# <Axes: >

# %%
msno.bar(df) # 결측치가 아닌 데이터 갯수
# Out:
# <Axes: >

# %%
# 결측치가 있는 컬럼에 대해 변수별 상관관계
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# ## ① df 변수의 컬럼들을 확인하고 상위 3줄, 하위3줄을 출력한다.

# %%
df.head(3)
# Out:
#                  상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1  MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2  MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0    비알코올     I21201          카페   I56229  ...  1111014000100280021026727
# 1  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010800113080025020133
# 2  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1120012200100040011000899
#
#       건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0     NaN   서울특별시 종로구 삼청로 122-1  110230  3053  NaN  NaN  NaN  126.981840
# 1  강남오피스텔  서울특별시 서초구 서초대로73길 40  137856  6612  NaN   11  NaN  127.024563
# 2     NaN  서울특별시 성동구 용답중앙15길 18  133847  4805  NaN    1  NaN  127.054262
#
#           위도
# 0  37.586250
# 1  37.500924
# 2  37.564786
#
# [3 rows x 39 columns]

# %%
df.loc[:2]
# Out:
#                  상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1  MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2  MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0    비알코올     I21201          카페   I56229  ...  1111014000100280021026727
# 1  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010800113080025020133
# 2  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1120012200100040011000899
#
#       건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0     NaN   서울특별시 종로구 삼청로 122-1  110230  3053  NaN  NaN  NaN  126.981840
# 1  강남오피스텔  서울특별시 서초구 서초대로73길 40  137856  6612  NaN   11  NaN  127.024563
# 2     NaN  서울특별시 성동구 용답중앙15길 18  133847  4805  NaN    1  NaN  127.054262
#
#           위도
# 0  37.586250
# 1  37.500924
# 2  37.564786
#
# [3 rows x 39 columns]

# %%
df.iloc[:3]
# Out:
#                  상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800000033    부동산임대김은숙  NaN        I2       음식      I212
# 1  MA010120220800000036   한국황토건축연구소  NaN        L1      부동산      L102
# 2  MA010120220800000077  소망공인중개사사무소  NaN        L1      부동산      L102
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0    비알코올     I21201          카페   I56229  ...  1111014000100280021026727
# 1  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010800113080025020133
# 2  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1120012200100040011000899
#
#       건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0     NaN   서울특별시 종로구 삼청로 122-1  110230  3053  NaN  NaN  NaN  126.981840
# 1  강남오피스텔  서울특별시 서초구 서초대로73길 40  137856  6612  NaN   11  NaN  127.024563
# 2     NaN  서울특별시 성동구 용답중앙15길 18  133847  4805  NaN    1  NaN  127.054262
#
#           위도
# 0  37.586250
# 1  37.500924
# 2  37.564786
#
# [3 rows x 39 columns]

# %%
df.tail(3)
# Out:
#                       상가업소번호      상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 696051  MA0101202502A0114732  지안영어교습소   NaN        P1       교육      P105
# 696052  MA0101202502A0114738   히어로스포츠   NaN        P1       교육      P106
# 696053  MA0101202502A0114753       안목  부산역점        I2       음식      I201
#
#        상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...  \
# 696051    일반 교육    P10501     입시·교과학원   P85501  ...
# 696052    기타 교육    P10603  요가/필라테스 학원   P85612  ...
# 696053       한식    I20101      백반/한정식   I56111  ...
#
#                            건물관리번호    건물명                    도로명주소   구우편번호  \
# 696051  2635010700114850004026754  대승프라임        부산광역시 해운대구 세실로 31  612842
# 696052  2653010600100740025010100    NaN   부산광역시 사상구 가야대로366번길 22  617833
# 696053  2617010100112000004006724    NaN  부산광역시 동구 중앙대로214번길 3-10  601838
#
#         신우편번호  동정보  층정보  호정보          경도         위도
# 696051  48111  NaN  NaN  NaN  129.179075  35.167826
# 696052  47006  NaN    3  NaN  129.012518  35.150000
# 696053  48733  NaN    1  NaN  129.041453  35.116696
#
# [3 rows x 39 columns]

# %%
df.iloc[3:]
# Out:
#                       상가업소번호      상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 3       MA010120220800000084      고향집   NaN        I2       음식      I201
# 4       MA010120220800000090     보석나라   NaN        G2       소매      G217
# 5       MA010120220800000099       청안   NaN        G2       소매      G209
# 6       MA010120220800000100    자하선인식   NaN        G2       소매      G205
# 7       MA010120220800000112      수피아   NaN        G2       소매      G217
# ...                      ...      ...   ...       ...      ...       ...
# 696049  MA0101202502A0111400   포마크파티룸   NaN        G2       소매      G220
# 696050  MA0101202502A0114219     정옥농장   NaN        G2       소매      G204
# 696051  MA0101202502A0114732  지안영어교습소   NaN        P1       교육      P105
# 696052  MA0101202502A0114738   히어로스포츠   NaN        P1       교육      P106
# 696053  MA0101202502A0114753       안목  부산역점        I2       음식      I201
#
#            상권업종중분류명 상권업종소분류코드       상권업종소분류명 표준산업분류코드  ...  \
# 3                한식    I20101         백반/한정식   I56111  ...
# 4         시계·귀금속 소매    G21701     시계/귀금속 소매업   G47830  ...
# 5       섬유·의복·신발 소매    G20902      여성 의류 소매업   G47412  ...
# 6            식료품 소매    G20508     건강보조식품 소매업   G47217  ...
# 7         시계·귀금속 소매    G21701     시계/귀금속 소매업   G47830  ...
# ...             ...       ...            ...      ...  ...
# 696049   애완동물·용품 소매    G22001  애완동물/애완용품 소매업   G47852  ...
# 696050        종합 소매    G20404           슈퍼마켓   G47129  ...
# 696051        일반 교육    P10501        입시·교과학원   P85501  ...
# 696052        기타 교육    P10603     요가/필라테스 학원   P85612  ...
# 696053           한식    I20101         백반/한정식   I56111  ...
#
#                            건물관리번호      건물명                    도로명주소   구우편번호  \
# 3       1111015400100800000000001      NaN      서울특별시 종로구 돈화문로4길 30  110430
# 4       1153010700103590008007958      NaN       서울특별시 구로구 개봉로3길 23  152815
# 5       1111014200100610000025897      NaN      서울특별시 종로구 삼청로 48-12  110230
# 6       1129013300108820006030505       상가       서울특별시 성북구 정릉로8길 67  136854
# 7       1111015600100260000000001  우리귀금속상가         서울특별시 종로구 종로 135  110123
# ...                           ...      ...                      ...     ...
# 696049  2623010300102670003027632      NaN    부산광역시 부산진구 중앙대로 763-1  614843
# 696050  2671025333102850002000001      NaN  부산광역시 기장군 장안읍 오리길 69-12  619951
# 696051  2635010700114850004026754    대승프라임        부산광역시 해운대구 세실로 31  612842
# 696052  2653010600100740025010100      NaN   부산광역시 사상구 가야대로366번길 22  617833
# 696053  2617010100112000004006724      NaN  부산광역시 동구 중앙대로214번길 3-10  601838
#
#         신우편번호  동정보  층정보  호정보          경도         위도
# 3        3193  NaN  NaN  NaN  126.993820  37.570025
# 4        8353  NaN    1  NaN  126.855046  37.486242
# 5        3053  NaN    1  NaN  126.980562  37.580466
# 6        2812  NaN    1  NaN  126.998709  37.608407
# 7        3138  NaN  NaN  NaN  126.992472  37.570736
# ...       ...  ...  ...  ...         ...        ...
# 696049  47251  NaN    4  NaN  129.061019  35.160630
# 696050  46030  NaN  NaN  NaN  129.268218  35.369200
# 696051  48111  NaN  NaN  NaN  129.179075  35.167826
# 696052  47006  NaN    3  NaN  129.012518  35.150000
# 696053  48733  NaN    1  NaN  129.041453  35.116696
#
# [696051 rows x 39 columns]

# %% [markdown]
# ## ② df 변수의 결측치를 제외한 데이터 개수 및 dtype들을 출력(dtypes함수)하고 변수가 사용되는 메모리 사용량 확인한다

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696054 entries, 0 to 696053
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     696054 non-null  object
#  1   상호명        696053 non-null  object
#  2   지점명        64452 non-null   object
#  3   상권업종대분류코드  696054 non-null  object
#  4   상권업종대분류명   696054 non-null  object
#  5   상권업종중분류코드  696054 non-null  object
#  6   상권업종중분류명   696054 non-null  object
#  7   상권업종소분류코드  696054 non-null  object
#  8   상권업종소분류명   696054 non-null  object
#  9   표준산업분류코드   695839 non-null  object
#  10  표준산업분류명    695839 non-null  object
#  11  시도코드       696054 non-null  int64
#  12  시도명        696054 non-null  object
#  13  시군구코드      696054 non-null  int64
#  14  시군구명       696054 non-null  object
#  15  행정동코드      696054 non-null  int64
#  16  행정동명       696054 non-null  object
#  17  법정동코드      696054 non-null  int64
#  18  법정동명       696054 non-null  object
#  19  지번코드       696054 non-null  int64
#  20  대지구분코드     696054 non-null  int64
#  21  대지구분명      696054 non-null  object
#  22  지번본번지      695991 non-null  float64
#  23  지번부번지      585538 non-null  float64
#  24  지번주소       696054 non-null  object
#  25  도로명코드      696054 non-null  int64
#  26  도로명        696054 non-null  object
#  27  건물본번지      696053 non-null  float64
#  28  건물부번지      94582 non-null   float64
#  29  건물관리번호     696053 non-null  object
#  30  건물명        317191 non-null  object
#  31  도로명주소      696054 non-null  object
#  32  구우편번호      696054 non-null  int64
#  33  신우편번호      696054 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        454431 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         696054 non-null  float64
#  38  위도         696054 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 207.1+ MB

# %% [markdown]
# ## ③ 결측치를 확인하고 결측치가 없는 컬럼을 포함하여 시각화(정렬전 bar plot, barh plot, 정렬 후 bar plot, barh plot)

# %%
# 열별 결측치 개수
missing_cnt= df.isnull().sum()
missing_cnt.head()
# Out:
# 상가업소번호            0
# 상호명               1
# 지점명          631602
# 상권업종대분류코드         0
# 상권업종대분류명          0
# dtype: int64

# %%
# missing_cnt.plot(kind='bar')
missing_cnt.plot.bar(rot= 45, figsize=(20, 3))
# Out:
# <Axes: >

# %%
missing_cnt_sorted = missing_cnt.sort_values(ascending=False)
missing_cnt_sorted.plot(kind='bar', figsize=(20,3))
# Out:
# <Axes: >

# %%
missing_cnt.sort_values().plot(kind='barh', figsize=(10,10))
# Out:
# <Axes: >

# %%
missing_cnt
# Out:
# 상가업소번호            0
# 상호명               1
# 지점명          631602
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드        215
# 표준산업분류명         215
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지            63
# 지번부번지        110516
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             1
# 건물부번지        601472
# 건물관리번호            1
# 건물명          378863
# 도로명주소             0
# 구우편번호             0
# 신우편번호             0
# 동정보          696054
# 층정보          241623
# 호정보          696054
# 경도                0
# 위도                0
# dtype: int64

# %% [markdown]
# ## ④ 결측치가 없는 컬럼는 제외하고 시각화(정렬전 bar plot, barh plot, 정렬 후 bar plot, barh plot).

# %%
only_missing_cnt=missing_cnt[missing_cnt != 0]
only_missing_cnt
# Out:
# 상호명              1
# 지점명         631602
# 표준산업분류코드       215
# 표준산업분류명        215
# 지번본번지           63
# 지번부번지       110516
# 건물본번지            1
# 건물부번지       601472
# 건물관리번호           1
# 건물명         378863
# 동정보         696054
# 층정보         241623
# 호정보         696054
# dtype: int64

# %%
only_missing_cnt.plot.bar(figsize=(20,5),
                         rot=0,
                         ylim=[0, 800000])
# plt.text(0, 1, 1)
# plt.text(12-0.2, 696054, 696054) for문으로 대체
for idx, val in enumerate(only_missing_cnt):
    plt.text(idx-0.3, val, val, size=15, color='r', weight='bold', va='bottom')

# %%
g = sns.barplot(x=only_missing_cnt.index,
           y=only_missing_cnt)
for idx, val in enumerate(only_missing_cnt):
    plt.text(idx-0.3, val, val, size=15, color='r', weight='bold', va='bottom')
#     plt.ylim([0, 800000])
g.set_ylim([0,800000])
plt.show()

# %%
only_missing_cnt_sorted = only_missing_cnt.sort_values(ascending=False)
only_missing_cnt_sorted.plot.bar(rot=30,
                                ylim=[0, 800000])
for idx, val in enumerate(only_missing_cnt_sorted):
    plt.text(idx-0.3, val, val, size=15, color='r', weight='bold', va='bottom')
#     plt.ylim([0, 800000])
plt.grid(axis='y')
plt.title('결측치 갯수', color='r', fontsize=20, weight='bold')
# Out:
# Text(0.5, 1.0, '결측치 갯수')

# %%
g = sns.barplot(y=only_missing_cnt_sorted.index,
           x=only_missing_cnt_sorted)
for idx, val in enumerate(only_missing_cnt_sorted):
    plt.text(val, idx, val, size=15, color='r', weight='bold', va='center')
#     plt.ylim([0, 800000])
g.set_xlim([0,800000])
plt.show()

# %% [markdown]
# # 4. df 데이터 셋에서 사용하지 않을 컬럼은 제거
# ## ① 결측치가 너무 많은 컬럼은 제거한다. 결측치가 너무 많은 상위 9개 컬럼은 제거함

# %%
not_use = df.isna().sum().sort_values(ascending=False).head(9)
not_use.index
# Out:
# Index(['호정보', '동정보', '지점명', '건물부번지', '건물명', '층정보', '지번부번지', '표준산업분류코드',
#        '표준산업분류명'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696054 entries, 0 to 696053
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     696054 non-null  object
#  1   상호명        696053 non-null  object
#  2   지점명        64452 non-null   object
#  3   상권업종대분류코드  696054 non-null  object
#  4   상권업종대분류명   696054 non-null  object
#  5   상권업종중분류코드  696054 non-null  object
#  6   상권업종중분류명   696054 non-null  object
#  7   상권업종소분류코드  696054 non-null  object
#  8   상권업종소분류명   696054 non-null  object
#  9   표준산업분류코드   695839 non-null  object
#  10  표준산업분류명    695839 non-null  object
#  11  시도코드       696054 non-null  int64
#  12  시도명        696054 non-null  object
#  13  시군구코드      696054 non-null  int64
#  14  시군구명       696054 non-null  object
#  15  행정동코드      696054 non-null  int64
#  16  행정동명       696054 non-null  object
#  17  법정동코드      696054 non-null  int64
#  18  법정동명       696054 non-null  object
#  19  지번코드       696054 non-null  int64
#  20  대지구분코드     696054 non-null  int64
#  21  대지구분명      696054 non-null  object
#  22  지번본번지      695991 non-null  float64
#  23  지번부번지      585538 non-null  float64
#  24  지번주소       696054 non-null  object
#  25  도로명코드      696054 non-null  int64
#  26  도로명        696054 non-null  object
#  27  건물본번지      696053 non-null  float64
#  28  건물부번지      94582 non-null   float64
#  29  건물관리번호     696053 non-null  object
#  30  건물명        317191 non-null  object
#  31  도로명주소      696054 non-null  object
#  32  구우편번호      696054 non-null  int64
#  33  신우편번호      696054 non-null  int64
#  34  동정보        0 non-null       float64
#  35  층정보        454431 non-null  object
#  36  호정보        0 non-null       float64
#  37  경도         696054 non-null  float64
#  38  위도         696054 non-null  float64
# dtypes: float64(8), int64(9), object(22)
# memory usage: 207.1+ MB

# %%
# 컬럼삭제 전 메모리 사용량 : 207.1+ MB
print('컬럼 제거전 shape : ', df.shape)
df.drop(not_use.index, axis=1, inplace=True)
print('컬럼 제거후 shape : ', df.shape)
# Out:
# 컬럼 제거전 shape :  (696054, 39)
# 컬럼 제거후 shape :  (696054, 30)

# %% [markdown]
# ## ② 컬럼명에 “코드”나 “번호”가 있는 컬럼은 분석에 사용되지 않을 예정입니다. 제거함( df.columns.str.contains(“코드|번호”) 이용).

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명',
#        '상권업종소분류코드', '상권업종소분류명', '시도코드', '시도명', '시군구코드', '시군구명', '행정동코드',
#        '행정동명', '법정동코드', '법정동명', '지번코드', '대지구분코드', '대지구분명', '지번본번지', '지번주소',
#        '도로명코드', '도로명', '건물본번지', '건물관리번호', '도로명주소', '구우편번호', '신우편번호', '경도',
#        '위도'],
#       dtype='object')

# %%
cols = df.columns

# %%
cols[(cols.str.find('코드')!=-1) | (cols.str.find('번호')!=-1)]
# Out:
# Index(['상가업소번호', '상권업종대분류코드', '상권업종중분류코드', '상권업종소분류코드', '시도코드', '시군구코드',
#        '행정동코드', '법정동코드', '지번코드', '대지구분코드', '도로명코드', '건물관리번호', '구우편번호',
#        '신우편번호'],
#       dtype='object')

# %%
# 
cols[cols.str.contains('코드 |번호')]
# Out:
# Index(['상가업소번호', '건물관리번호', '구우편번호', '신우편번호'], dtype='object')

# %%
print('제거 전 shape :', df.shape)
df.drop(drop_col, axis=1, inplace=True)
print('제거 후 shape :', df.shape)
# Out:
# 제거 전 shape : (696054, 30)
# 제거 후 shape : (696054, 26)

# %%
# 컬럼 제거 후 메모리 사용량 확인

# %% [markdown]
# # ※ df 파일 io ※

# %%
df.to_csv('C:/ai_x/download/shareData/상가정보_250331/서울부산상가정보(최종).csv',
         index=False)

# %%
df.read_csv('C:/ai_x/download/shareData/상가정보_250331/서울부산상가정보(최종).csv')

# %% [markdown]
# # 5. df 데이터 셋의 값을 가져온다(loc함수, iloc함수등을 사용하기도 하고 사용하지 않기도 하며 서브셋을 가져온다)
# ## ① 상호명 필드만 가져온다

# %%
df['상호명'] # 시리즈
df[['상호명']] # 데이터프레임
df.loc[:,['상호명']]
# Out:
#                상호명
# 0         부동산임대김은숙
# 1        한국황토건축연구소
# 2       소망공인중개사사무소
# 3              고향집
# 4             보석나라
# ...            ...
# 696049      포마크파티룸
# 696050        정옥농장
# 696051     지안영어교습소
# 696052      히어로스포츠
# 696053          안목
#
# [696054 rows x 1 columns]

# %% [markdown]
# ## ② 상호명의 종류별 데이터수를 가져온다(df.상호명.value_counts()이용)

# %%
df['상호명'].value_counts()
# Out:
# 컴퓨터수리         576
# 입시·교과학원       351
# 입주청소          308
# 김밥천국          232
# 현대공인중개사사무소    195
#              ...
# 오오토리            1
# 이천산업            1
# 미가뷰티            1
# 가산문고            1
# 지안영어교습소         1
# Name: 상호명, Length: 535747, dtype: int64

# %%
df.groupby('상호명')['시군구명'].count().sort_values(ascending=False)
# Out:
# 상호명
# 컴퓨터수리                  576
# 입시·교과학원                351
# 입주청소                   308
# 김밥천국                   232
# 현대공인중개사사무소             195
#                       ...
# 본푸드서비스삼표점주               1
# 본푸드서비스본우리집밥이마트수서점        1
# 본푸드서비스본우리집밥본그룹본사점        1
# 본푸드서비스본우리집밥대치위담한방병원      1
# ［주］세일캠퍼스                 1
# Name: 시군구명, Length: 535747, dtype: int64

# %%
# 결측치가 업는 컬럼 확인
df.isna().sum()
# Out:
# 상호명           1
# 상권업종대분류코드     0
# 상권업종대분류명      0
# 상권업종중분류코드     0
# 상권업종중분류명      0
# 상권업종소분류코드     0
# 상권업종소분류명      0
# 시도코드          0
# 시도명           0
# 시군구코드         0
# 시군구명          0
# 행정동코드         0
# 행정동명          0
# 법정동코드         0
# 법정동명          0
# 지번코드          0
# 대지구분코드        0
# 대지구분명         0
# 지번본번지        63
# 지번주소          0
# 도로명코드         0
# 도로명           0
# 건물본번지         1
# 도로명주소         0
# 경도            0
# 위도            0
# dtype: int64

# %% [markdown]
# ## ③ “상호명”과 "도로명주소” 컬럼 가져오기

# %%
df.loc[df.상호명=='김밥천국', ['상호명','도로명주소']]
df[ ['상호명','도로명주소']]
# Out:
#                상호명                    도로명주소
# 0         부동산임대김은숙      서울특별시 종로구 삼청로 122-1
# 1        한국황토건축연구소     서울특별시 서초구 서초대로73길 40
# 2       소망공인중개사사무소     서울특별시 성동구 용답중앙15길 18
# 3              고향집      서울특별시 종로구 돈화문로4길 30
# 4             보석나라       서울특별시 구로구 개봉로3길 23
# ...            ...                      ...
# 696049      포마크파티룸    부산광역시 부산진구 중앙대로 763-1
# 696050        정옥농장  부산광역시 기장군 장안읍 오리길 69-12
# 696051     지안영어교습소        부산광역시 해운대구 세실로 31
# 696052      히어로스포츠   부산광역시 사상구 가야대로366번길 22
# 696053          안목  부산광역시 동구 중앙대로214번길 3-10
#
# [696054 rows x 2 columns]

# %% [markdown]
# ## ④ 0~2행을 출력하라 (head()함수를 이용하지 않고, loc과 iloc을 이용)

# %%
df.loc[0:2]
df.loc[0:3]
# Out:
#           상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드    상권업종소분류명  \
# 0    부동산임대김은숙        I2       음식      I212    비알코올     I21201          카페
# 1   한국황토건축연구소        L1      부동산      L102  부동산 서비스    L10203  부동산 중개/대리업
# 2  소망공인중개사사무소        L1      부동산      L102  부동산 서비스    L10203  부동산 중개/대리업
# 3         고향집        I2       음식      I201       한식    I20101      백반/한정식
#
#    시도코드    시도명  시군구코드  ... 대지구분코드  대지구분명   지번본번지                   지번주소  \
# 0    11  서울특별시  11110  ...      1     대지    28.0    서울특별시 종로구 삼청동 28-21
# 1    11  서울특별시  11650  ...      1     대지  1308.0  서울특별시 서초구 서초동 1308-25
# 2    11  서울특별시  11200  ...      1     대지     4.0     서울특별시 성동구 용답동 4-11
# 3    11  서울특별시  11110  ...      1     대지    80.0       서울특별시 종로구 장사동 80
#
#           도로명코드                도로명  건물본번지                 도로명주소          경도  \
# 0  111103100007      서울특별시 종로구 삼청로  122.0   서울특별시 종로구 삼청로 122-1  126.981840
# 1  116504163432  서울특별시 서초구 서초대로73길   40.0  서울특별시 서초구 서초대로73길 40  127.024563
# 2  112004109494  서울특별시 성동구 용답중앙15길   18.0  서울특별시 성동구 용답중앙15길 18  127.054262
# 3  111104100055   서울특별시 종로구 돈화문로4길   30.0   서울특별시 종로구 돈화문로4길 30  126.993820
#
#           위도
# 0  37.586250
# 1  37.500924
# 2  37.564786
# 3  37.570025
#
# [4 rows x 26 columns]

# %% [markdown]
# # 6. 기술 통계값 보기

# %% [markdown]
# - [Descriptive statistics - Wikipedia](https://en.wikipedia.org/wiki/Descriptive_statistics)
# - [Computations / descriptive stats](https://pandas.pydata.org/docs/reference/frame.html#computations-descriptive-stats)
# - [표준 편차 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/표준편차)
# * describe()를 사용하면 데이터 요약을 볼 수 있음(기술통계량)
#     - 기본적으로 수치형 데이터를 요약
#     - include, exclude 옵션으로 다른 데이터 타입의 요약 수치 출력
#     - count, min, max, mean, median, 1사분위수, 3사분위수
#
# ### **개별 기술 통계값 구하기**
#
# * [Computations / descriptive stats](https://pandas.pydata.org/docs/reference/frame.html#computations-descriptive-stats)
# * count : 결측치를 제외한 값 갯수
# * min, max: 최솟값, 최댓값
# * argmin, argmax : 최솟값 인덱스, 최댓값 인덱스 반환
# * quantile 특정 사분위수에 해당하는 값을 반환 (0~1 사이)
#     * 0.25 : 1사분위 수
#     * 0.5 : 2사분위수 (quantile 의 기본 값)
#     * 0.75 : 3사분위수
# * sum 수치 데이터의 합계
# * mean 평균
# * median 중앙값(중간값:데이터를 한 줄로 세웠을 때 가운데 위치하는 값, 중앙값이 짝수일 때는 가운데 2개 값의 평균을 구함)
#
# * std, var 표준편차, 분산을 계산
# * cumsum 맨 첫 번째 성분부터 각 성분까지의 누적합을 계산 (0 번째 부터 계속 더해짐)
# * cumprod 맨 첫번째 성분부터 각 성분까지의 누적곱을 계산 (1 번째 부터 계속 곱해짐)
# * cov, corr() : 공분산, 상관계수
# * skew 왜도 (오른쪽으로 치우침= 왜도<0, 왼쪽으로 치우침=왜도>0)
# * kurt 첨도

# %% [markdown]
# ## ① df 데이터셋의 요약기술 통계량

# %%
df.describe() #  수치형 컬럼에 대한
# Out:
#                 시도코드          시군구코드         행정동코드         법정동코드          지번코드  \
# count  696054.000000  696054.000000  6.960540e+05  6.960540e+05  6.960540e+05
# mean       14.351830   14789.639618  1.479025e+07  1.478975e+09  1.478857e+18
# std         6.248419    6205.162837  6.205150e+06  6.205164e+08  6.206604e+17
# min        11.000000   11110.000000  1.111052e+07  1.111010e+09  1.165011e+14
# 25%        11.000000   11350.000000  1.135062e+07  1.135010e+09  1.135011e+18
# 50%        11.000000   11560.000000  1.156071e+07  1.156013e+09  1.156013e+18
# 75%        11.000000   11740.000000  1.174052e+07  1.174010e+09  1.174010e+18
# max        26.000000   26710.000000  2.671033e+07  2.671033e+09  2.671033e+18
#
#               대지구분코드          지번본번지         도로명코드          건물본번지  \
# count  696054.000000  695991.000000  6.960540e+05  696053.000000
# mean        1.001191     480.607357  1.479000e+11     143.589911
# std         0.034490     512.914069  6.205159e+10     263.204012
# min         1.000000       1.000000  1.111020e+11       1.000000
# 25%         1.000000     111.000000  1.135031e+11      19.000000
# 50%         1.000000     335.000000  1.156042e+11      47.000000
# 75%         1.000000     684.000000  1.174020e+11     152.000000
# max         2.000000    6435.000000  2.671049e+11    3646.000000
#
#                   경도             위도
# count  696054.000000  696054.000000
# mean      127.455853      37.009921
# std         0.866655       0.990450
# min       126.768186      34.989747
# 25%       126.943200      37.474714
# 50%       127.034361      37.514521
# 75%       127.130725      37.560269
# max       129.292220      37.692604

# %%
df.describe(include='object') 
# object 형에 대한 기술 통게량 : 최빈값, 최빈값 갯수, 데이터 종류 갯수, 데이터 갯수
# Out:
#            상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명  \
# count   696053    696054   696054    696054   696054    696054   696054
# unique  535747        10       10        75       75       247      247
# top      컴퓨터수리        I2       음식      I201       한식    I20101   백반/한정식
# freq       576    193508   193508     71670    71670     34283    34283
#
#            시도명    시군구명    행정동명    법정동명   대지구분명               지번주소  \
# count   696054  696054  696054  696054  696054             696054
# unique       2      39     628     647       2             220969
# top      서울특별시     강남구    역삼1동     서초동      대지  서울특별시 송파구 문정동 634
# freq    540517   64716   13655   18140  695225                938
#
#                    도로명             도로명주소
# count           696054            696054
# unique           18864            223665
# top     서울특별시 강남구 테헤란로  서울특별시 송파구 충민로 66
# freq              4462              1200

# %%
df.describe(exclude='object') 
# object 형을 제외한 기술 통계량
# Out:
#                 시도코드          시군구코드         행정동코드         법정동코드          지번코드  \
# count  696054.000000  696054.000000  6.960540e+05  6.960540e+05  6.960540e+05
# mean       14.351830   14789.639618  1.479025e+07  1.478975e+09  1.478857e+18
# std         6.248419    6205.162837  6.205150e+06  6.205164e+08  6.206604e+17
# min        11.000000   11110.000000  1.111052e+07  1.111010e+09  1.165011e+14
# 25%        11.000000   11350.000000  1.135062e+07  1.135010e+09  1.135011e+18
# 50%        11.000000   11560.000000  1.156071e+07  1.156013e+09  1.156013e+18
# 75%        11.000000   11740.000000  1.174052e+07  1.174010e+09  1.174010e+18
# max        26.000000   26710.000000  2.671033e+07  2.671033e+09  2.671033e+18
#
#               대지구분코드          지번본번지         도로명코드          건물본번지  \
# count  696054.000000  695991.000000  6.960540e+05  696053.000000
# mean        1.001191     480.607357  1.479000e+11     143.589911
# std         0.034490     512.914069  6.205159e+10     263.204012
# min         1.000000       1.000000  1.111020e+11       1.000000
# 25%         1.000000     111.000000  1.135031e+11      19.000000
# 50%         1.000000     335.000000  1.156042e+11      47.000000
# 75%         1.000000     684.000000  1.174020e+11     152.000000
# max         2.000000    6435.000000  2.671049e+11    3646.000000
#
#                   경도             위도
# count  696054.000000  696054.000000
# mean      127.455853      37.009921
# std         0.866655       0.990450
# min       126.768186      34.989747
# 25%       126.943200      37.474714
# 50%       127.034361      37.514521
# 75%       127.130725      37.560269
# max       129.292220      37.692604

# %%
df.describe(exclude=['object','int64']) 
# object 형을 제외한 기술 통계량
# Out:
#                지번본번지          건물본번지             경도             위도
# count  695991.000000  696053.000000  696054.000000  696054.000000
# mean      480.607357     143.589911     127.455853      37.009921
# std       512.914069     263.204012       0.866655       0.990450
# min         1.000000       1.000000     126.768186      34.989747
# 25%       111.000000      19.000000     126.943200      37.474714
# 50%       335.000000      47.000000     127.034361      37.514521
# 75%       684.000000     152.000000     127.130725      37.560269
# max      6435.000000    3646.000000     129.292220      37.692604

# %%
# object 형의 기술통계량 df.describe(include='object')
# object형 테이터
df.select_dtypes('object').head(1)
# Out:
#         상호명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드 상권업종소분류명    시도명  \
# 0  부동산임대김은숙        I2       음식      I212    비알코올     I21201       카페  서울특별시
#
#   시군구명 행정동명 법정동명 대지구분명                 지번주소            도로명  \
# 0  종로구  삼청동  삼청동    대지  서울특별시 종로구 삼청동 28-21  서울특별시 종로구 삼청로
#
#                  도로명주소
# 0  서울특별시 종로구 삼청로 122-1

# %% [markdown]
# ## ② df 데이터셋의 “지번본번지", "건물본번지” 컬럼의 데이터 개수와  dtype 메모리 사용량을 확인한다.

# %%
df[['지번본번지','건물본번지']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696054 entries, 0 to 696053
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   지번본번지   695991 non-null  float64
#  1   건물본번지   696053 non-null  float64
# dtypes: float64(2)
# memory usage: 10.6 MB

# %% [markdown]
# ## ③ “위도", "경도” 컬럼만의 요약 기술통계량

# %%
# 두 컬럼의 타입
df[['위도','경도']].dtypes
# Out:
# 위도    float64
# 경도    float64
# dtype: object

# %%
df[['위도','경도']].describe()
# Out:
#                   위도             경도
# count  696054.000000  696054.000000
# mean       37.009921     127.455853
# std         0.990450       0.866655
# min        34.989747     126.768186
# 25%        37.474714     126.943200
# 50%        37.514521     127.034361
# 75%        37.560269     127.130725
# max        37.692604     129.292220

# %% [markdown]
# # 7. 단별량 수치형 변수 시각화
# ## ① 위도의 빈도표를 시각화 : plot.hist, hist, sns.displot, sns.histplot

# %%
df['위도'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['위도'].hist(bins=50)
# Out:
# <Axes: >

# %%
g = sns.displot(data=df, x='위도', bins=50, rug=True)
g.fig.set_size_inches(15, 3)

# %%
sns.histplot(data=df, x='위도', bins=50)
plt.show()

# %%
sns.histplot(data=df, x='위도', bins=50)
plt.axvline(df['위도'].mean(), color='r', linestyle=':', linewidth=3)
plt.annotate('평균',
            xytext=(35.3, 130000), # 글자 좌표
            xy = (df['위도'].mean(), 100000), # 화살표가 가르킬 좌표
            arrowprops=dict(arrowstyle='->',
                           connectionstyle='angle3',
                           color='r'),
            fontsize=30,
            color='r' 
            )
plt.axvline(df['위도'].median(), color='b', linewidth=3)
plt.annotate('중위수',
            xytext=(37.6, 130000), # 글자 좌표
            xy = (df['위도'].median(), 100000), # 화살표가 가르킬 좌표
            arrowprops={'arrowstyle':'->',
                        'connectionstyle':'angle3',
                        'color':'b'},
            fontsize=30,
            color='b' 
            )
plt.show()

# %%
# 왜도 : 평균을 기준으로 치우친 정도
# 오른쪽으로 치우침 : 왜도가 음수. 평균<중위수
# 왼쪽으로 치우침 : 왜도가 양수. 중위수<평균
df['위도'].skew()
# Out:
# -1.3235077358631402

# %% [markdown]
# ## ② 경도의 빈도표를 시각화 : plot.hist, hist, sns.displot, sns.histplot

# %%
sns.histplot(data=df, x='경도', bins=50)
plt.axvline(df.경도.mean(), color='r', linewidth=3)
plt.annotate('평균',
            xytext=(128, 130000), # 글자 좌표
            xy = (df['경도'].mean(), 100000), # 화살표가 가르킬 좌표
            arrowprops=dict(arrowstyle='->',
                           connectionstyle='angle3',
                           color='r'),
            fontsize=30,
            color='r' 
            )
plt.axvline(df.경도.median(), color='b', linewidth=3)
plt.annotate('중위수',
            xytext=(126.8, 130000), # 글자 좌표
            xy = (df['경도'].median(), 100000), # 화살표가 가르킬 좌표
            arrowprops=dict(arrowstyle='->',
                           connectionstyle='angle',
                           color='b'),
            fontsize=20,
            color='b' 
            )
# Out:
# Text(126.8, 130000, '중위수')

# %%
df.경도.skew()
# Out:
# 1.3076255398048455

# %%
# 확인필요

# %% [markdown]
# # 8. 상관계수
# -  두 변수 간에 어떤 선형적 관계를 갖고 있는 지를 분석하는 방법
# - [상관 분석 - 위키백과, 우리 모두의 백과사전M](https://ko.wikipedia.org/wiki/상관_분석)
#
# - 결과의 해석 : r 값은 X 와 Y 가 완전히 동일하면 +1, 전혀 다르면 0, 반대방향으로 완전히 동일 하면 –1 을 가진다. 결정계수(coefficient of determination)는 $r^2$로 계산하며 이것은 X 로부터 Y를 예측할 수 있는 정도를 의미한다.
# - ([수학기호 사이트 참조](https://matplotlib.org/2.0.2/users/mathtext.html))
#
# - 일반적으로
#     * r이 -1.0과 -0.7 사이이면, 강한 음적 선형관계,
#     * r이 -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계,
#     * r이 -0.3과 -0.1 사이이면, 약한 음적 선형관계,
#     * r이 -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계,
#     * r이 +0.1과 +0.3 사이이면, 약한 양적 선형관계,
#     * r이 +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계,
#     * r이 +0.7과 +1.0 사이이면, 강한 양적 선형관계로 해석한다.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Correlation_examples2.svg/220px-Correlation_examples2.svg.png" width="600">
#
# 이미지 출처 : [위키백과](https://ko.wikipedia.org/wiki/상관_분석)

# %% [markdown]
# ## ① 전체 숫자 컬럼끼리의 상관계수

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#             시도코드     시군구코드     행정동코드     법정동코드      지번코드    대지구분코드     지번본번지  \
# 시도코드    1.000000  0.999549  0.999549  0.999549  0.999332  0.022375  0.181261
# 시군구코드   0.999549  1.000000  1.000000  1.000000  0.999779  0.022346  0.187890
# 행정동코드   0.999549  1.000000  1.000000  1.000000  0.999779  0.022346  0.187890
# 법정동코드   0.999549  1.000000  1.000000  1.000000  0.999779  0.022346  0.187890
# 지번코드    0.999332  0.999779  0.999779  0.999779  1.000000  0.022347  0.187890
# 대지구분코드  0.022375  0.022346  0.022346  0.022346  0.022347  1.000000 -0.028289
# 지번본번지   0.181261  0.187890  0.187890  0.187890  0.187890 -0.028289  1.000000
# 도로명코드   0.999549  1.000000  1.000000  1.000000  0.999779  0.022346  0.187889
# 건물본번지  -0.011130 -0.007925 -0.007925 -0.007925 -0.007985  0.001480  0.057312
# 경도      0.995742  0.995538  0.995538  0.995538  0.995319  0.022469  0.169355
# 위도     -0.998777 -0.998960 -0.998960 -0.998960 -0.998737 -0.022169 -0.189570
#
#            도로명코드     건물본번지        경도        위도
# 시도코드    0.999549 -0.011130  0.995742 -0.998777
# 시군구코드   1.000000 -0.007925  0.995538 -0.998960
# 행정동코드   1.000000 -0.007925  0.995538 -0.998960
# 법정동코드   1.000000 -0.007925  0.995538 -0.998960
# 지번코드    0.999779 -0.007985  0.995319 -0.998737
# 대지구분코드  0.022346  0.001480  0.022469 -0.022169
# 지번본번지   0.187889  0.057312  0.169355 -0.189570
# 도로명코드   1.000000 -0.007931  0.995538 -0.998960
# 건물본번지  -0.007931  1.000000 -0.005815  0.012164
# 경도      0.995538 -0.005815  1.000000 -0.993565
# 위도     -0.998960  0.012164 -0.993565  1.000000

# %% [markdown]
# ## ② 상관계수를 이용하여 heatmap 시각화

# %%
sns.heatmap(corr, annot=True, fmt='.2f', cmap='Blues')
plt.show()

# %%
a = np.array([[2.0, 1, 3],
            [-1, -1, 3]]) # 3행 3열짜리 배열
np.ones(  (2,2), dtype=bool)  매개변수에 온 구조의 배열에 1로
# Out:
#   Cell In[151], line 3
#     np.ones(  (2,2), dtype=bool)  매개변수에 온 구조의 배열에 1로
#                                                   ^
# SyntaxError: invalid decimal literal

# %%
# 여까지

# %%
temp = np.ones_like(a) # a변수와 구조가 같은 배열에 1
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# # 9. 경도와 위도 컬럼을 이용하여 산점도
# - [Anscombe’s quartet — seaborn 0.10.0 documentation](https://seaborn.pydata.org/examples/anscombes_quartet.html)
