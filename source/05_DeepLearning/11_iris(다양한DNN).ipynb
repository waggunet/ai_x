# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:10pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:5px;}
table.dataframe{font-size:15px;
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:10pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:5px;}
# table.dataframe{font-size:15px;
# </style>

# %%
# import
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# 데이터 생성 및 전처리(라벨인코딩만 하고, 원핫인코딩X)

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %% [markdown]
# # 1. 기본적인 DNN(원핫인코딩X)

# %%
# 모델 설정
# model = Sequential()
# model.add(Input(4,))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model = Sequential([
    Input(4,),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.summary() # 250+1530+93 = 1873개 파라미터
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 50)                250
#
#  dense_10 (Dense)            (None, 30)                1530
#
#  dense_11 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습설정
model.compile(loss='sparse_categorical_crossentropy', # 라벨인코딩만 되어 있는 경우
             optimizer='adam',
             metrics=['accuracy'])
# 학습
earlyStropping = EarlyStopping(patience=50) # monitor='val_loss' 기본값
hist = model.fit(train_X, train_y, epochs=1000,
                validation_split=0.2,
                callbacks=[earlyStropping])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 1.2046 - accuracy: 0.1667 - val_loss: 1.1233 - val_accuracy: 0.0741
# Epoch 2/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0921 - accuracy: 0.3056 - val_loss: 1.1008 - val_accuracy: 0.2222
# Epoch 3/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0347 - accuracy: 0.3611 - val_loss: 1.0677 - val_accuracy: 0.2222
# Epoch 4/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9803 - accuracy: 0.3704 - val_loss: 1.0079 - val_accuracy: 0.2963
# Epoch 5/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9399 - accuracy: 0.4352 - val_loss: 0.9568 - val_accuracy: 0.6296
# Epoch 6/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9076 - accuracy: 0.6296 - val_loss: 0.9141 - val_accuracy: 0.6667
# Epoch 7/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8755 - accuracy: 0.7593 - val_loss: 0.8704 - val_accuracy: 0.7778
# Epoch 8/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8392 - accuracy: 0.8241 - val_loss: 0.8367 - val_accuracy: 0.7037
# Epoch 9/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8009 - accuracy: 0.6852 - val_loss: 0.8044 - val_accuracy: 0.7037
# Epoch 10/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7643 - accuracy: 0.6852 - val_loss: 0.7568 - val_accuracy: 0.7037
# Epoch 11/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7331 - accuracy: 0.7222 - val_loss: 0.7123 - val_accuracy: 0.7778
# Epoch 12/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7076 - accuracy: 0.7778 - val_loss: 0.6819 - val_accuracy: 0.7778
# Epoch 13/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6820 - accuracy: 0.8241 - val_loss: 0.6517 - val_accuracy: 0.7778
# Epoch 14/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6605 - accuracy: 0.7963 - val_loss: 0.6272 - val_accuracy: 0.7778
# Epoch 15/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6371 - accuracy: 0.8241 - val_loss: 0.5994 - val_accuracy: 0.8148
# Epoch 16/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6165 - accuracy: 0.8889 - val_loss: 0.5773 - val_accuracy: 0.8889
# Epoch 17/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5991 - accuracy: 0.9167 - val_loss: 0.5596 - val_accuracy: 0.8889
# Epoch 18/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5797 - accuracy: 0.8889 - val_loss: 0.5472 - val_accuracy: 0.8148
# Epoch 19/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5630 - accuracy: 0.8519 - val_loss: 0.5301 - val_accuracy: 0.7778
# Epoch 20/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5465 - accuracy: 0.8426 - val_loss: 0.5060 - val_accuracy: 0.8148
# Epoch 21/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5306 - accuracy: 0.8704 - val_loss: 0.4784 - val_accuracy: 0.8889
# Epoch 22/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.9259 - val_loss: 0.4605 - val_accuracy: 0.8889
# Epoch 23/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4989 - accuracy: 0.9259 - val_loss: 0.4475 - val_accuracy: 0.8889
# Epoch 24/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4846 - accuracy: 0.9074 - val_loss: 0.4391 - val_accuracy: 0.8519
# Epoch 25/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4724 - accuracy: 0.8611 - val_loss: 0.4331 - val_accuracy: 0.8148
# Epoch 26/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4615 - accuracy: 0.8611 - val_loss: 0.4179 - val_accuracy: 0.8519
# Epoch 27/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4482 - accuracy: 0.8796 - val_loss: 0.4074 - val_accuracy: 0.8889
# Epoch 28/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.8981 - val_loss: 0.3938 - val_accuracy: 0.8889
# Epoch 29/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4230 - accuracy: 0.9259 - val_loss: 0.3742 - val_accuracy: 0.9259
# Epoch 30/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4189 - accuracy: 0.9630 - val_loss: 0.3607 - val_accuracy: 0.9259
# Epoch 31/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4076 - accuracy: 0.9630 - val_loss: 0.3587 - val_accuracy: 0.9259
# Epoch 32/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3938 - accuracy: 0.9444 - val_loss: 0.3613 - val_accuracy: 0.8889
# Epoch 33/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3864 - accuracy: 0.9167 - val_loss: 0.3563 - val_accuracy: 0.8889
# Epoch 34/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3827 - accuracy: 0.9444 - val_loss: 0.3383 - val_accuracy: 0.9630
# Epoch 35/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3667 - accuracy: 0.9630 - val_loss: 0.3276 - val_accuracy: 0.9630
# Epoch 36/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3594 - accuracy: 0.9630 - val_loss: 0.3147 - val_accuracy: 0.9259
# Epoch 37/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3511 - accuracy: 0.9630 - val_loss: 0.3106 - val_accuracy: 0.9630
# Epoch 38/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3410 - accuracy: 0.9630 - val_loss: 0.3139 - val_accuracy: 0.9259
# Epoch 39/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3341 - accuracy: 0.9444 - val_loss: 0.3058 - val_accuracy: 0.9630
# Epoch 40/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3242 - accuracy: 0.9630 - val_loss: 0.2903 - val_accuracy: 0.9630
# Epoch 41/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3178 - accuracy: 0.9722 - val_loss: 0.2791 - val_accuracy: 0.9259
# Epoch 42/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3158 - accuracy: 0.9722 - val_loss: 0.2728 - val_accuracy: 0.9259
# Epoch 43/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3053 - accuracy: 0.9722 - val_loss: 0.2723 - val_accuracy: 0.9630
# Epoch 44/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2927 - accuracy: 0.9722 - val_loss: 0.2667 - val_accuracy: 0.9630
# Epoch 45/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2856 - accuracy: 0.9722 - val_loss: 0.2636 - val_accuracy: 0.9630
# Epoch 46/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2774 - accuracy: 0.9630 - val_loss: 0.2543 - val_accuracy: 0.9630
# Epoch 47/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2713 - accuracy: 0.9630 - val_loss: 0.2404 - val_accuracy: 0.9259
# Epoch 48/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2644 - accuracy: 0.9722 - val_loss: 0.2371 - val_accuracy: 0.9630
# Epoch 49/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2628 - accuracy: 0.9630 - val_loss: 0.2430 - val_accuracy: 0.9630
# Epoch 50/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2483 - accuracy: 0.9630 - val_loss: 0.2282 - val_accuracy: 0.9630
# Epoch 51/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2355 - accuracy: 0.9722 - val_loss: 0.2140 - val_accuracy: 0.9259
# Epoch 52/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2300 - accuracy: 0.9722 - val_loss: 0.2118 - val_accuracy: 0.9630
# Epoch 53/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2263 - accuracy: 0.9630 - val_loss: 0.2204 - val_accuracy: 0.9630
# Epoch 54/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2175 - accuracy: 0.9630 - val_loss: 0.2042 - val_accuracy: 0.9630
# Epoch 55/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2103 - accuracy: 0.9815 - val_loss: 0.1965 - val_accuracy: 0.9630
# Epoch 56/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2050 - accuracy: 0.9815 - val_loss: 0.2001 - val_accuracy: 0.9630
# Epoch 57/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1973 - accuracy: 0.9722 - val_loss: 0.1863 - val_accuracy: 0.9630
# Epoch 58/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1934 - accuracy: 0.9722 - val_loss: 0.1819 - val_accuracy: 0.9630
# Epoch 59/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1885 - accuracy: 0.9815 - val_loss: 0.1902 - val_accuracy: 0.9630
# Epoch 60/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1839 - accuracy: 0.9722 - val_loss: 0.1752 - val_accuracy: 0.9630
# Epoch 61/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1772 - accuracy: 0.9722 - val_loss: 0.1675 - val_accuracy: 0.9259
# Epoch 62/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1739 - accuracy: 0.9815 - val_loss: 0.1666 - val_accuracy: 0.9630
# Epoch 63/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1735 - accuracy: 0.9722 - val_loss: 0.1720 - val_accuracy: 0.9630
# Epoch 64/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1665 - accuracy: 0.9722 - val_loss: 0.1581 - val_accuracy: 0.9630
# Epoch 65/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1609 - accuracy: 0.9815 - val_loss: 0.1546 - val_accuracy: 0.9630
# Epoch 66/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1568 - accuracy: 0.9815 - val_loss: 0.1539 - val_accuracy: 0.9630
# Epoch 67/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1542 - accuracy: 0.9815 - val_loss: 0.1537 - val_accuracy: 0.9630
# Epoch 68/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1514 - accuracy: 0.9815 - val_loss: 0.1482 - val_accuracy: 0.9630
# Epoch 69/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1468 - accuracy: 0.9815 - val_loss: 0.1484 - val_accuracy: 0.9630
# Epoch 70/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1439 - accuracy: 0.9815 - val_loss: 0.1476 - val_accuracy: 0.9630
# Epoch 71/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1415 - accuracy: 0.9815 - val_loss: 0.1423 - val_accuracy: 0.9630
# Epoch 72/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1373 - accuracy: 0.9815 - val_loss: 0.1354 - val_accuracy: 0.9630
# Epoch 73/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1361 - accuracy: 0.9907 - val_loss: 0.1319 - val_accuracy: 0.9259
# Epoch 74/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1353 - accuracy: 0.9815 - val_loss: 0.1381 - val_accuracy: 0.9630
# Epoch 75/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1310 - accuracy: 0.9815 - val_loss: 0.1323 - val_accuracy: 0.9630
# Epoch 76/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1266 - accuracy: 0.9907 - val_loss: 0.1266 - val_accuracy: 0.9259
# Epoch 77/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1266 - accuracy: 0.9815 - val_loss: 0.1244 - val_accuracy: 0.9259
# Epoch 78/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1284 - accuracy: 0.9907 - val_loss: 0.1302 - val_accuracy: 0.9630
# Epoch 79/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1222 - accuracy: 0.9815 - val_loss: 0.1212 - val_accuracy: 0.9259
# Epoch 80/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1220 - accuracy: 0.9815 - val_loss: 0.1189 - val_accuracy: 0.9259
# Epoch 81/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1210 - accuracy: 0.9907 - val_loss: 0.1211 - val_accuracy: 0.9630
# Epoch 82/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1158 - accuracy: 0.9907 - val_loss: 0.1217 - val_accuracy: 0.9630
# Epoch 83/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1160 - accuracy: 0.9815 - val_loss: 0.1197 - val_accuracy: 0.9630
# Epoch 84/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1123 - accuracy: 0.9815 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 85/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1111 - accuracy: 0.9907 - val_loss: 0.1143 - val_accuracy: 0.9630
# Epoch 86/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1093 - accuracy: 0.9907 - val_loss: 0.1124 - val_accuracy: 0.9630
# Epoch 87/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1080 - accuracy: 0.9907 - val_loss: 0.1120 - val_accuracy: 0.9630
# Epoch 88/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1058 - accuracy: 0.9907 - val_loss: 0.1165 - val_accuracy: 0.9630
# Epoch 89/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1060 - accuracy: 0.9815 - val_loss: 0.1106 - val_accuracy: 0.9630
# Epoch 90/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1037 - accuracy: 0.9907 - val_loss: 0.1067 - val_accuracy: 0.9259
# Epoch 91/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1029 - accuracy: 0.9907 - val_loss: 0.1080 - val_accuracy: 0.9630
# Epoch 92/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1003 - accuracy: 0.9907 - val_loss: 0.1095 - val_accuracy: 0.9630
# Epoch 93/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.9815 - val_loss: 0.1136 - val_accuracy: 0.9630
# Epoch 94/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0984 - accuracy: 0.9815 - val_loss: 0.1043 - val_accuracy: 0.9259
# Epoch 95/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0962 - accuracy: 0.9815 - val_loss: 0.1037 - val_accuracy: 0.9259
# Epoch 96/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1003 - accuracy: 0.9815 - val_loss: 0.1018 - val_accuracy: 0.9259
# Epoch 97/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0942 - accuracy: 0.9907 - val_loss: 0.1029 - val_accuracy: 0.9630
# Epoch 98/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0939 - accuracy: 0.9907 - val_loss: 0.1055 - val_accuracy: 0.9630
# Epoch 99/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0933 - accuracy: 0.9907 - val_loss: 0.1044 - val_accuracy: 0.9630
# Epoch 100/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0926 - accuracy: 0.9907 - val_loss: 0.1011 - val_accuracy: 0.9630
# Epoch 101/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0920 - accuracy: 0.9907 - val_loss: 0.0976 - val_accuracy: 0.9259
# Epoch 102/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0893 - accuracy: 0.9907 - val_loss: 0.0979 - val_accuracy: 0.9630
# Epoch 103/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0955 - accuracy: 0.9815 - val_loss: 0.1038 - val_accuracy: 0.9630
# Epoch 104/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0890 - accuracy: 0.9907 - val_loss: 0.0957 - val_accuracy: 0.9259
# Epoch 105/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0868 - accuracy: 0.9907 - val_loss: 0.0946 - val_accuracy: 0.9259
# Epoch 106/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0881 - accuracy: 0.9907 - val_loss: 0.0962 - val_accuracy: 0.9630
# Epoch 107/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0858 - accuracy: 0.9907 - val_loss: 0.0944 - val_accuracy: 0.9259
# Epoch 108/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0876 - accuracy: 0.9907 - val_loss: 0.0937 - val_accuracy: 0.9259
# Epoch 109/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0855 - accuracy: 0.9815 - val_loss: 0.0955 - val_accuracy: 0.9630
# Epoch 110/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0828 - accuracy: 0.9907 - val_loss: 0.0983 - val_accuracy: 0.9630
# Epoch 111/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0854 - accuracy: 0.9907 - val_loss: 0.0959 - val_accuracy: 0.9630
# Epoch 112/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0820 - accuracy: 0.9907 - val_loss: 0.0925 - val_accuracy: 0.9259
# Epoch 113/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0814 - accuracy: 0.9907 - val_loss: 0.0918 - val_accuracy: 0.9259
# Epoch 114/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0815 - accuracy: 0.9907 - val_loss: 0.0917 - val_accuracy: 0.9259
# Epoch 115/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0806 - accuracy: 0.9907 - val_loss: 0.0968 - val_accuracy: 0.9630
# Epoch 116/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0837 - accuracy: 0.9907 - val_loss: 0.0943 - val_accuracy: 0.9630
# Epoch 117/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0781 - accuracy: 0.9907 - val_loss: 0.0898 - val_accuracy: 0.9259
# Epoch 118/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.9907 - val_loss: 0.0896 - val_accuracy: 0.9259
# Epoch 119/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0790 - accuracy: 0.9815 - val_loss: 0.0896 - val_accuracy: 0.9259
# Epoch 120/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0817 - accuracy: 0.9907 - val_loss: 0.0958 - val_accuracy: 0.9630
# Epoch 121/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9907 - val_loss: 0.0897 - val_accuracy: 0.9630
# Epoch 122/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0947 - accuracy: 0.9722 - val_loss: 0.0959 - val_accuracy: 0.9630
# Epoch 123/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0890 - accuracy: 0.9722 - val_loss: 0.0917 - val_accuracy: 0.9630
# Epoch 124/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0774 - accuracy: 0.9907 - val_loss: 0.0924 - val_accuracy: 0.9630
# Epoch 125/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0811 - accuracy: 0.9907 - val_loss: 0.0881 - val_accuracy: 0.9259
# Epoch 126/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0782 - accuracy: 0.9907 - val_loss: 0.0943 - val_accuracy: 0.9630
# Epoch 127/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0778 - accuracy: 0.9907 - val_loss: 0.0878 - val_accuracy: 0.9630
# Epoch 128/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9907 - val_loss: 0.0875 - val_accuracy: 0.9630
# Epoch 129/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0752 - accuracy: 0.9907 - val_loss: 0.0894 - val_accuracy: 0.9630
# Epoch 130/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0756 - accuracy: 0.9907 - val_loss: 0.0869 - val_accuracy: 0.9630
# Epoch 131/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0722 - accuracy: 0.9907 - val_loss: 0.0876 - val_accuracy: 0.9630
# Epoch 132/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9907 - val_loss: 0.0876 - val_accuracy: 0.9630
# Epoch 133/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0745 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9259
# Epoch 134/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0725 - accuracy: 0.9907 - val_loss: 0.0851 - val_accuracy: 0.9259
# Epoch 135/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0712 - accuracy: 0.9907 - val_loss: 0.0871 - val_accuracy: 0.9630
# Epoch 136/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9259
# Epoch 137/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9907 - val_loss: 0.0848 - val_accuracy: 0.9259
# Epoch 138/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0730 - accuracy: 0.9815 - val_loss: 0.0846 - val_accuracy: 0.9259
# Epoch 139/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0715 - accuracy: 0.9907 - val_loss: 0.0920 - val_accuracy: 0.9630
# Epoch 140/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0732 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 141/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0727 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 142/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0688 - accuracy: 0.9907 - val_loss: 0.0843 - val_accuracy: 0.9259
# Epoch 143/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0698 - accuracy: 0.9907 - val_loss: 0.0843 - val_accuracy: 0.9259
# Epoch 144/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0692 - accuracy: 0.9907 - val_loss: 0.0873 - val_accuracy: 0.9630
# Epoch 145/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0693 - accuracy: 0.9907 - val_loss: 0.0855 - val_accuracy: 0.9630
# Epoch 146/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0680 - accuracy: 0.9907 - val_loss: 0.0843 - val_accuracy: 0.9259
# Epoch 147/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 0.9907 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 148/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 0.9907 - val_loss: 0.0879 - val_accuracy: 0.9630
# Epoch 149/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0690 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9630
# Epoch 150/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0669 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 151/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0694 - accuracy: 0.9815 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 152/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0686 - accuracy: 0.9907 - val_loss: 0.0873 - val_accuracy: 0.9630
# Epoch 153/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0695 - accuracy: 0.9907 - val_loss: 0.0855 - val_accuracy: 0.9630
# Epoch 154/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0665 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9259
# Epoch 155/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0690 - accuracy: 0.9815 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 156/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0687 - accuracy: 0.9907 - val_loss: 0.0846 - val_accuracy: 0.9630
# Epoch 157/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0659 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9259
# Epoch 158/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0655 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 159/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9907 - val_loss: 0.0830 - val_accuracy: 0.9630
# Epoch 160/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0644 - accuracy: 0.9907 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 161/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9907 - val_loss: 0.0821 - val_accuracy: 0.9259
# Epoch 162/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0666 - accuracy: 0.9907 - val_loss: 0.0824 - val_accuracy: 0.9259
# Epoch 163/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9259
# Epoch 164/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0678 - accuracy: 0.9815 - val_loss: 0.0815 - val_accuracy: 0.9259
# Epoch 165/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0672 - accuracy: 0.9907 - val_loss: 0.0879 - val_accuracy: 0.9630
# Epoch 166/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0656 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9259
# Epoch 167/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9907 - val_loss: 0.0832 - val_accuracy: 0.9259
# Epoch 168/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0660 - accuracy: 0.9907 - val_loss: 0.0817 - val_accuracy: 0.9259
# Epoch 169/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0627 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 170/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0632 - accuracy: 0.9907 - val_loss: 0.0844 - val_accuracy: 0.9630
# Epoch 171/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0656 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9630
# Epoch 172/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0651 - accuracy: 0.9907 - val_loss: 0.0846 - val_accuracy: 0.9259
# Epoch 173/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0686 - accuracy: 0.9815 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 174/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.9815 - val_loss: 0.0816 - val_accuracy: 0.9259
# Epoch 175/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0864 - val_accuracy: 0.9630
# Epoch 176/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0654 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9630
# Epoch 177/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0663 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 178/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0653 - accuracy: 0.9815 - val_loss: 0.0817 - val_accuracy: 0.9259
# Epoch 179/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 180/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0633 - accuracy: 0.9907 - val_loss: 0.0853 - val_accuracy: 0.9630
# Epoch 181/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0616 - accuracy: 0.9907 - val_loss: 0.0818 - val_accuracy: 0.9259
# Epoch 182/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0609 - accuracy: 0.9907 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 183/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0618 - accuracy: 0.9815 - val_loss: 0.0817 - val_accuracy: 0.9259
# Epoch 184/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0598 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9630
# Epoch 185/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0880 - val_accuracy: 0.9630
# Epoch 186/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9630
# Epoch 187/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0670 - accuracy: 0.9907 - val_loss: 0.0823 - val_accuracy: 0.9259
# Epoch 188/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0626 - accuracy: 0.9815 - val_loss: 0.0819 - val_accuracy: 0.9259
# Epoch 189/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0631 - accuracy: 0.9815 - val_loss: 0.0817 - val_accuracy: 0.9259
# Epoch 190/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0604 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9259
# Epoch 191/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0598 - accuracy: 0.9907 - val_loss: 0.0844 - val_accuracy: 0.9630
# Epoch 192/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9907 - val_loss: 0.0830 - val_accuracy: 0.9259
# Epoch 193/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0600 - accuracy: 0.9907 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 194/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0586 - accuracy: 0.9907 - val_loss: 0.0831 - val_accuracy: 0.9259
# Epoch 195/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0622 - accuracy: 0.9815 - val_loss: 0.0818 - val_accuracy: 0.9259
# Epoch 196/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0599 - accuracy: 0.9815 - val_loss: 0.0818 - val_accuracy: 0.9259
# Epoch 197/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0617 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9630
# Epoch 198/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0611 - accuracy: 0.9907 - val_loss: 0.0820 - val_accuracy: 0.9259
# Epoch 199/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0609 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9259
# Epoch 200/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0594 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 201/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0585 - accuracy: 0.9907 - val_loss: 0.0821 - val_accuracy: 0.9259
# Epoch 202/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0580 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9259
# Epoch 203/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 204/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0640 - accuracy: 0.9907 - val_loss: 0.0848 - val_accuracy: 0.9630
# Epoch 205/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9259
# Epoch 206/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0608 - accuracy: 0.9815 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 207/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0831 - val_accuracy: 0.9259
# Epoch 208/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0843 - val_accuracy: 0.9630
# Epoch 209/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0588 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9259
# Epoch 210/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9259
# Epoch 211/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0564 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9259
# Epoch 212/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0582 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9259
# Epoch 213/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0583 - accuracy: 0.9815 - val_loss: 0.0824 - val_accuracy: 0.9259
# Epoch 214/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩을 하지 않고 라벨인코딩까지만 해야 작동. numpy배열

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 머신러닝 3장 교안 43page
mlp_model = MLPClassifier(hidden_layer_sizes=(50,30),
                     activation='relu', 
                     solver='adam',
                     alpha=0.0001, # 과적합 방지 강도
                     batch_size=40,
                     max_iter=1000, # epoch
                     early_stopping=True, # 조기 종료 활성화(val_loss)
                     n_iter_no_change=50, # patience
                     warm_start=False, # True일 경우 이전학습에 이어서 학습 
                     validation_fraction=0.1) # 검증셋 비율

# %%
mlp_model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True, hidden_layer_sizes=(50, 30),
#               max_iter=1000, n_iter_no_change=50)

# %%
# 모델 평가 : accuracy(test_X,test_y), recall, precision(test_y, yhat)
from sklearn.metrics import recall_score, precision_score
accuracy = mlp_model.score(test_X, test_y)
yhat = mlp_model.predict(test_X)
recall = recall_score(test_y, yhat, average='weighted')
precision = precision_score(test_y, yhat, average='weighted')
print('정확도 :', accuracy)
print('재현율 :', recall)
print('정밀도 :', precision)
print('교차표\n', pd.crosstab(test_y, yhat, 
                           rownames=['실제'],
                           colnames=['예측']))
# Out:
# 정확도 : 1.0
# 재현율 : 1.0
# 정밀도 : 1.0
# 교차표
#  예측  0  1  2
# 실제
# 0   5  0  0
# 1   0  5  0
# 2   0  0  5

# %% [markdown]
# # 3. 클래스 이용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', optimizer='adam'):
        # 모델 구성
#         model = Sequential()
#         model.add(Input(input_dim,))
#         model.add(Dense(50, activation=activation))
#         model.add(Dense(30, activation=activation))
#         model.add(Dense(3, activation='softmax'))
        model = Sequential([
            Input(input_dim,) ,
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(3, activation='softmax')
        ])
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        return model

# %%
# %%time
# 모델
model = DNNClassifier.build(input_dim=4, activation='relu')
model.summary()
# 모델 학습
hist = model.fit(train_X, train_y,
                epochs=500,
                validation_split=0.2,
                verbose=0)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 50)                250
#
#  dense_10 (Dense)            (None, 30)                1530
#
#  dense_11 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 13.3 s
# Wall time: 11.8 s

# %%
loss, accuracy = model.evaluate(test_X, test_y)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0384 - accuracy: 1.0000
# (0.0383770614862442, 1.0)

# %% [markdown]
# # 4. 함수형 API이용하기
# - 병렬처리 : 속도 높이려고
# - 레지듀얼블록(Residual block) : 모델의 성능을 높이려고(자연어처리,이미지처리)

# %%
# import
import numpy as np
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras import Model # 모델 생성(입력층과 출력층을 이용)
from tensorflow.keras.layers import Dense, Input, add # add :레지듀얼블록 
from tensorflow.keras.layers import concatenate # 병렬처리시

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %%
# 기존의 model 스타일 4 -> 50 -> 30 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=30, activation='relu')(dense1)
dense3 = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=dense3)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=20,
         validation_split=0.2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 4)]               0
#
#  dense_3 (Dense)             (None, 50)                250
#
#  dense_4 (Dense)             (None, 30)                1530
#
#  dense_5 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 1s 50ms/step - loss: 1.6666 - accuracy: 0.3426 - val_loss: 1.1741 - val_accuracy: 0.2963
# Epoch 2/20
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3786 - accuracy: 0.3426 - val_loss: 1.0111 - val_accuracy: 0.2963
# Epoch 3/20
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1435 - accuracy: 0.4167 - val_loss: 0.9052 - val_accuracy: 0.7407
# Epoch 4/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9683 - accuracy: 0.6296 - val_loss: 0.8334 - val_accuracy: 0.8148
# Epoch 5/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8612 - accuracy: 0.8056 - val_loss: 0.7912 - val_accuracy: 0.7407
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7977 - accuracy: 0.7130 - val_loss: 0.7626 - val_accuracy: 0.7037
# Epoch 7/20
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7517 - accuracy: 0.6574 - val_loss: 0.7268 - val_accuracy: 0.7037
# Epoch 8/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7169 - accuracy: 0.6574 - val_loss: 0.6846 - val_accuracy: 0.7037
# Epoch 9/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6879 - accuracy: 0.6574 - val_loss: 0.6409 - val_accuracy: 0.7037
# Epoch 10/20
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6556 - accuracy: 0.6574 - val_loss: 0.5961 - val_accuracy: 0.7037
# Epoch 11/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6213 - accuracy: 0.6667 - val_loss: 0.5615 - val_accuracy: 0.7037
# Epoch 12/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5954 - accuracy: 0.7315 - val_loss: 0.5279 - val_accuracy: 0.7778
# Epoch 13/20
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5728 - accuracy: 0.8519 - val_loss: 0.4976 - val_accuracy: 0.8519
# Epoch 14/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5548 - accuracy: 0.8889 - val_loss: 0.4733 - val_accuracy: 0.8889
# Epoch 15/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5369 - accuracy: 0.8796 - val_loss: 0.4567 - val_accuracy: 0.8519
# Epoch 16/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5192 - accuracy: 0.8704 - val_loss: 0.4408 - val_accuracy: 0.8519
# Epoch 17/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5042 - accuracy: 0.8611 - val_loss: 0.4279 - val_accuracy: 0.8519
# Epoch 18/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4901 - accuracy: 0.8611 - val_loss: 0.4116 - val_accuracy: 0.8519
# Epoch 19/20
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4779 - accuracy: 0.8519 - val_loss: 0.3985 - val_accuracy: 0.8519
# Epoch 20/20
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4663 - accuracy: 0.8611 - val_loss: 0.3832 - val_accuracy: 0.8519

# %%
# 병렬처리
# 4 -> 160(50,80,30로 병렬처리) -> 32 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(160, activation='relu')(input_)의 병렬처리
dense4 = Dense(32, activation='relu')(x)
output = Dense(3, activation='softmax')(dense4)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 4)]          0           []
#
#  dense_6 (Dense)                (None, 50)           250         ['input_3[0][0]']
#
#  dense_7 (Dense)                (None, 80)           400         ['input_3[0][0]']
#
#  dense_8 (Dense)                (None, 30)           150         ['input_3[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_6[0][0]',
#                                                                   'dense_7[0][0]',
#                                                                   'dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 32)           5152        ['concatenate[0][0]']
#
#  dense_10 (Dense)               (None, 3)            99          ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 6,051
# Trainable params: 6,051
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
# 레지듀얼블록(Residual Block):딥러닝에서 딥한 네트워크가 학습이 잘 되지 않을 때
# 4 -> 50 -> 50 ->(레지듀얼)-> 3
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(3, activation='softmax')(dense3)
model = Model(inputs=input_, outputs=output)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=500,
         validation_split=0.2, verbose=0)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 4)]          0           []
#
#  dense_14 (Dense)               (None, 50)           250         ['input_5[0][0]']
#
#  dense_15 (Dense)               (None, 50)           2550        ['dense_14[0][0]']
#
#  add_1 (Add)                    (None, 50)           0           ['dense_14[0][0]',
#                                                                   'dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 3)            153         ['add_1[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________
# CPU times: total: 13.4 s
# Wall time: 11.9 s

# %%
model.evaluate(test_X, test_y)
# Out:
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0347 - accuracy: 1.0000
# [0.034681063145399094, 1.0]
