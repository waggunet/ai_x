# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:14pt;}
div.output {font-size:14pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:10pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:5px;}
table.dataframe{font-size:15px;
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:14pt;}
# div.output {font-size:14pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:10pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:5px;}
# table.dataframe{font-size:15px;
# </style>

# %% [markdown]
# # <span style="color:red">ch2. LLM활용의 기본 개념(Ollama)</span>
# # 1. LLM을 활용하여 답변 생성하기
#
# ## 1) Ollama 이용한 로컬 LLM 이용
# 성능은 GPT, Claude 같은 모델 보다는 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ###  ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull deepseek-r1:1.5b(windows키+R => powershell)

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke("What is the capital of korea")
result # 추론모델<think>~<think>
# Out:
# AIMessage(content='<think>\n\n</think>\n\nThe capital of Korea, also known as South Korea, is Seoul.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-06-25T02:10:11.5223978Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1130090100, 'load_duration': 20955300, 'prompt_eval_count': 10, 'prompt_eval_duration': 51548900, 'eval_count': 19, 'eval_duration': 1057585900, 'model_name': 'deepseek-r1:1.5b'}, id='run--c3e29fd0-c9bb-4fa6-b8d5-5d2551ce9ac1-0', usage_metadata={'input_tokens': 10, 'output_tokens': 19, 'total_tokens': 29})

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
result = llm.invoke("대한민국의 수도는 어디야?")
result # 추론모델<think>~<think>
# Out:
# AIMessage(content='<think>\n\n</think>\n\n대한민국의 수도는 도와를 기록한 랜마카스 퍼ȯ어에서 originates\xa0하기 위해 도와를 기록하고 있다. 이 퍼 월드는 exterior properties, such as geology and tectonics, are influenced by the underlying surface features.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2025-06-25T02:11:45.6062388Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4287683300, 'load_duration': 18540000, 'prompt_eval_count': 13, 'prompt_eval_duration': 341551200, 'eval_count': 71, 'eval_duration': 3927592100, 'model_name': 'deepseek-r1:1.5b'}, id='run--19831ff8-b97d-4397-ad6f-e821d9673534-0', usage_metadata={'input_tokens': 13, 'output_tokens': 71, 'total_tokens': 84})

# %% [markdown]
# ###  ollama.com 다운로드 -> 설치 -> 모델 pull
# - ollama pull llama3.2:1b(windows키+R => powershell)
# - llama " 공식적으로 한글지원 안됨 (llama 3.1 405b 한글지원 가능->llama 3.3 70b)
# - exaone : 공식적으로 한글지원

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
result = llm.invoke("What is the capital of korea?")
result
# Out:
# AIMessage(content='The capital of South Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T02:19:01.0545487Z', 'done': True, 'done_reason': 'stop', 'total_duration': 621795000, 'load_duration': 20725300, 'prompt_eval_count': 33, 'prompt_eval_duration': 57881600, 'eval_count': 9, 'eval_duration': 543188100, 'model_name': 'llama3.2:1b'}, id='run--9b1a6ea5-74a1-4b15-8695-6077bf5099c0-0', usage_metadata={'input_tokens': 33, 'output_tokens': 9, 'total_tokens': 42})

# %%
result.content
# Out:
# 'The capital of South Korea is Seoul.'

# %%
llm.invoke("한국의 수도는 어디야?")
result.content
# Out:
# 'The capital of South Korea is Seoul.'

# %% [markdown]
# # open ai 활용
# - pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI
# llm = ChatOpenAI(model="gpt-4o-mini")
# result = llm.invoke("What is the capital of korea?")
# result => 에러 이유 :  OPENAI_API_KEY 환경변수 부재

# %%
# 환경변수 가져오기
from dotenv import load_dotenv
import os
load_dotenv() # 이렇게만 해도 됨
# os.getenv('OPENAI_API_KEY')
# Out:
# True

# %%
# 코랩에서 OPENAI_API_KEY 읽어오기(.env 사용불가)
# 보안키 추가 후
# from google.colab import userdata
# userdata.get('OPENAI_API_KEY')

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano", 
                 # openai_api_key=os.get('OPENAI_API_KEY')
                )
result = llm.invoke("What is the capital of korea? Answer me in Korean")
result
# Out:
# AIMessage(content='한국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 18, 'total_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_38343a2f8f', 'id': 'chatcmpl-BmBfJkBplDL2tJgZXTSXQhuu8qt5R', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--d71e7850-da45-4df9-ab17-55163bb36b95-0', usage_metadata={'input_tokens': 18, 'output_tokens': 7, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# 모든 모델의 키가 OPENAI_API_KEY는 아님
# Claude -> Anthropic
# Azure, Upstage, Bedrock : 에러 메시지 참조하여 환경변수 생성

# %%
# from langchain_openai import AzureOpenAI
# llm = AzureOpenAI(model="gpt-4.1-nano")
# llm.invoke("What is the capital of korea? Answer me in Korean")
# 에러를 내면 OPENAI_API_VERSION 환경변수가 필요하다는 메시지
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[33], line 2
#       1 from langchain_openai import AzureOpenAI
# ----> 2 llm = AzureOpenAI(model="gpt-4.1-nano")
#       3 llm.invoke("What is the capital of korea? Answer me in Korean")
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\load\serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
# File ~\anaconda3\envs\llm\lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for AzureOpenAI
#   Value error, Must provide either the `api_version` argument or the `OPENAI_API_VERSION` environment variable [type=value_error, input_value={'model': 'gpt-4.1-nano', 'model_kwargs': {}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-3-5-sonet-20240620")
# result = llm.invoke("What is the capital of korea? Answer me in Korean")
# 에러메시지를 봐도 환경변수 이름을 알 수 없음 -> ChatAnthropic  검색 후, 
# langchain docs 에서 명시한 ANTHROPIC_API_KEY 이름의 환경변수 설정

# %% [markdown]
# # 2.  렝체인 스타일로 프롬프트 작성하기
# - 프롬프트 : llm호출시 사용하는 질문

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
llm.invoke("What is the capital of korea?")
# 프로토 타입 : 스트링
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T05:19:58.8198329Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2672129700, 'load_duration': 1682549400, 'prompt_eval_count': 33, 'prompt_eval_duration': 553826700, 'eval_count': 8, 'eval_duration': 433170000, 'model_name': 'llama3.2:1b'}, id='run--5b2c69f8-d0db-4b6a-b602-852780bfbc01-0', usage_metadata={'input_tokens': 33, 'output_tokens': 8, 'total_tokens': 41})

# %%
result.content
# Out:
# '한국의 수도는 서울입니다.'

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
# llm.invoke(0)
# 프로토 타입 : 스트링

# ValueError: Invalid input type <class 'int'>. Must be a PromptValue, str, or list of BaseMessages.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 from langchain_ollama import ChatOllama
#       2 llm = ChatOllama(model="llama3.2:1b")
# ----> 3 llm.invoke(0)
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:373, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
#     372         self.generate_prompt(
# --> 373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File ~\anaconda3\envs\llm\lib\site-packages\langchain_core\language_models\chat_models.py:358, in BaseChatModel._convert_input(self, model_input)
#     353     return ChatPromptValue(messages=convert_to_messages(model_input))
#     354 msg = (
#     355     f"Invalid input type {type(model_input)}. "
#     356     "Must be a PromptValue, str, or list of BaseMessages."
#     357 )
# --> 358 raise ValueError(msg)
#
# ValueError: Invalid input type <class 'int'>. Must be a PromptValue, str, or list of BaseMessages.

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="llama3.2:1b")
# llm.invoke(0) 에러발생 
# 프로토 타입 : 스트링, PromptValue, BaseMessages 리스트

# %% [markdown]
# ## 1) 기본 프롬프트 템플릿 사용
# - PromptTemplate을 사용하여 변수가 포함된 템플릿 작성

# %%
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b")
prompt_template = PromptTemplate(
    template = "What is the capital of {country}", #{}안의 값을 새로운 값으로 대입 가능
    input_variables = ["country"]
)
prompt = prompt_template.invoke({"country":"Korea"})
print(prompt)
llm.invoke(prompt)
# Out:
# text='What is the capital of Korea'
# AIMessage(content="The capital of South Korea is Seoul. However, it's worth noting that North Korea also claims Seoul as its own capital, and the two countries have a long-standing dispute over the issue.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T05:45:36.7927037Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4766043800, 'load_duration': 1691280200, 'prompt_eval_count': 31, 'prompt_eval_duration': 610800400, 'eval_count': 39, 'eval_duration': 2462965600, 'model_name': 'llama3.2:1b'}, id='run--f4253eed-1f93-43d6-b568-e6d442d803ab-0', usage_metadata={'input_tokens': 31, 'output_tokens': 39, 'total_tokens': 70})

# %% [markdown]
# ## 2) 메시지 기반 프롬프트 작성
# - BaseMessages 리스트
# - BaseMessages 상속 받은 클래스 : AIMessage, HumanMessage, SystemMessage, ToolMesssage

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of France?")
]
llm.invoke(message_list)
# Out:
# AIMessage(content="That's a trick question! The capital of France is actually Paris, not Rome or Seoul. Rome is the capital of Italy, as we discussed earlier, and Paris is the capital of France.", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T06:36:09.034282Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5521299000, 'load_duration': 1484072300, 'prompt_eval_count': 86, 'prompt_eval_duration': 1502206600, 'eval_count': 40, 'eval_duration': 2526628800, 'model_name': 'llama3.2:1b'}, id='run--8d0ad6d3-2f60-4cca-88e2-e4c25f39af0b-0', usage_metadata={'input_tokens': 86, 'output_tokens': 40, 'total_tokens': 126})

# %%
# BaseMessage list로 하면 렝체인화X, ChatPromptTemplateX
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
llm = ChatOllama(model="llama3.2:1b")
message_list =[
    SystemMessage(content="You ara a helpful assistant!"),
    HumanMessage(content="What is the capital of Italy?"),
    AIMessage(content="The capital of Italy is Rome."),
    HumanMessage(content="What is the capital of Korea?"),
    AIMessage(content="The capital of Italy is Seoul."),
    HumanMessage(content="What is the capital of {country}?")
]
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate.from_messages(message_list)
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print(prompt)
# Out:
# messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Seoul.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of {country}?', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ## 3) ChatPromptTemplate 사용
# - BaseMessage 리스트 -> 튜플 리스트

# %%
# 위의 BaseMessage를 수정
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "You ara a helpful assistant!"),
    ("human", "What is the capital of {country}?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result.content
# Out:
# 어느 나라 수도가 궁금하세요?q
# 프롬프트 : messages=[SystemMessage(content='You ara a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of q?', additional_kwargs={}, response_metadata={})]
# 'I think there may be a little issue here. There are several countries called "Q" or "Quarantine", but I\'m assuming you might be referring to one specific country.\n\nIf you\'re thinking of Qatar, it\'s actually a small country in the Middle East, and its capital is Doha. Is that what you were looking for?'

# %%
chatPromptTemplate = ChatPromptTemplate.from_messages([
    ("system", "당신은 대한민국 전문 도우미야!"),
    ("human", "{country}의 수도가 어디예요?"),
])
country = input("어느 나라 수도가 궁금하세요?")
prompt = chatPromptTemplate.invoke({"country":country})
print("프롬프트 :",prompt)
result = llm.invoke(prompt)
result
# Out:
# 어느 나라 수도가 궁금하세요?서울
# 프롬프트 : messages=[SystemMessage(content='당신은 대한민국 전문 도우미야!', additional_kwargs={}, response_metadata={}), HumanMessage(content='서울의 수도가 어디예요?', additional_kwargs={}, response_metadata={})]
# AIMessage(content='대도시인분이 주로 살고 있는 서울은 수도입니다. 서울은 2006년 7월 1일부터 수도로 선출되었다. Seoul은 한국에서 가장 큰 도시이며, 한국의 수도를 지니며, 대한민국 중부에 위치한cities입니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T07:56:16.6856163Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4661109200, 'load_duration': 31030700, 'prompt_eval_count': 43, 'prompt_eval_duration': 535873300, 'eval_count': 62, 'eval_duration': 4093519200, 'model_name': 'llama3.2:1b'}, id='run--a007ed8b-9b2e-4729-9cbd-5cdef69637f8-0', usage_metadata={'input_tokens': 43, 'output_tokens': 62, 'total_tokens': 105})

# %% [markdown]
# # 3. 답변 형식을 컨트롤하기
# - invoke 실행결과는 AIMessage() -> String이나 json, 객체 : outputParser이용
# ## 1) 문자열 출력 파서 이용
# - StrOutputParser를 사용하여 LLM출력(AIMessage)을 단순 문자열로 변환

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
# 프롬프트 템플릿에 값 주입
prompt = prompt_template.invoke({"country":"Korea"})
print('프롬프트 : ',prompt)
result = llm.invoke(prompt)
print('llm 결과 :', type(result), result)
# 문자열 출력 파서를 이용하여 llm응답을 단순 문자열 변환
output_parser = StrOutputParser()
print('파서 결과 :',output_parser.invoke(result))
# Out:
# 프롬프트 :  text='What is the capital of Korea. Return the name of the city only'
# llm 결과 : <class 'langchain_core.messages.ai.AIMessage'> content='Seoul' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T07:57:20.8630271Z', 'done': True, 'done_reason': 'stop', 'total_duration': 644147200, 'load_duration': 26885100, 'prompt_eval_count': 39, 'prompt_eval_duration': 486227100, 'eval_count': 3, 'eval_duration': 129626900, 'model_name': 'llama3.2:1b'} id='run--52af4680-a86a-4654-a9d0-76e805b7e61c-0' usage_metadata={'input_tokens': 39, 'output_tokens': 3, 'total_tokens': 42}
# 파서 결과 : Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %%
# PromptTemplate(변수설정) => ChatPromptTemplate(변수설정, system과 모법답안 지정)
llm = ChatOllama(model="llama3.2:1b")

chat_prompt_template = ChatPromptTemplate([
    ("system", "You are a helpful assistant with expertise in South Korea."),
    ("human", "What is the capital of {country}? Return the name if the city only.")
])

output_parser = StrOutputParser()

output_parser.invoke(llm.invoke(chat_prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) Json 출력 파서 이용
# - json()으로 응답하기를 원하지만, 우선 어떤 형식으로 반환되는 확인
# - {"name":"홍","age":22}(json) /{'name':'홍','age':22}(dict)

# %%
from langchain_core.output_parsers import JsonOutputParser
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
prompt = country_detail_prompt.invoke({"country":"Korea"})
print(type(prompt), prompt)
# Json output 파서
output_parser = JsonOutputParser()
ai_message = llm.invoke(prompt)
print(type(prompt), ai_message)
json_result = output_parser.invoke(ai_message)
print(type(json_result), json_result)
# Out:
# <class 'langchain_core.prompt_values.StringPromptValue'> text='Give following information about Korea\n    - Capital\n    - Population\n    - Language\n    - Currency\n    return it is JSON format and return the JSON dictionary only'
# <class 'langchain_core.prompt_values.StringPromptValue'> content='```\n{\n  "capital": "Seoul",\n  "population": 51.8,\n  "language": "Korean",\n  "currency": {\n    "name": "Korean Won (KRW)",\n    "code": "KRW"\n  }\n}\n```' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2025-06-25T07:58:19.558775Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4627257100, 'load_duration': 23342700, 'prompt_eval_count': 59, 'prompt_eval_duration': 800315900, 'eval_count': 58, 'eval_duration': 3803062500, 'model_name': 'llama3.2:1b'} id='run--04d78839-a271-4c30-a00c-89649eedaeae-0' usage_metadata={'input_tokens': 59, 'output_tokens': 58, 'total_tokens': 117}
# <class 'dict'> {'capital': 'Seoul', 'population': 51.8, 'language': 'Korean', 'currency': {'name': 'Korean Won (KRW)', 'code': 'KRW'}}

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
output_parser = JsonOutputParser()
info = output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":
                                                                     "Korea"})))
info
# Out:
# {'capital': 'Seoul',
#  'population': '51,825,000',
#  'language': 'Korean (official)',
#  'currency': 'South Korean won'}

# %%
type(info)
# Out:
# dict

# %% [markdown]
# ## 3) 구조화된 출력 사용
# - Pydantic 모델을 사용하여 LLM 출력을 구조화된 형식으로 받기(JsonParser보다 훨씬 안정적)
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name = name
        self.is_active = is_active
user = User("1", "홍길동")
print(user)
# Out:
# <__main__.User object at 0x000001AB148810C0>

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    # gt=0:id>0, ge=0:id>=0, lt=0:id<0, le=0:le<=0
    id:int   = Field(gt=0,            description="id")
    name:str = Field(min_length=2,    description="name")
    is_active:bool=Field(default=True,description="id활성화")
user = User(id="1", name="홍길동")
print(user)
# Out:
# id=1 name='홍길동' is_active=True

# %%
country_detail_prompt = PromptTemplate(
    template = """Give following information about {country}
    - Capital
    - Population
    - Language
    - Currency
    return it is JSON format and return the JSON dictionary only""",
    input_variables = ["country"]    
)
class CountryDetail(BaseModel): # description: 더 정확한 출력 유도
    capital:str    = Field(description="the capital of the country")
    population:int = Field(description="the population of the country")
    language:str   = Field(description="the language of the country")
    currency:str   = Field(description="the currency of the country")
# 출력 형식 파서 + LLM
structedllm = llm.with_structured_output(CountryDetail)

# output_parser = JsonOutputParser()
# output_parser.invoke(llm.invoke(country_detail_prompt.invoke({"country":"Korea"})))

info = structedllm.invoke(country_detail_prompt.invoke({"country":"Korea"}))
type(info)
# Out:
# __main__.CountryDetail

# %%
print(info)
print(info.capital, info.population)
# Out:
# capital='Seoul' population=51 language='Korean' currency='Korean won'
# Seoul 51

# %%
print('info를 json :', info.model_dump_json()) # json()
print('info를 dict :', info.model_dump()) # dict()
# Out:
# info를 json : {"capital":"Seoul","population":51,"language":"Korean","currency":"Korean won"}
# info를 dict : {'capital': 'Seoul', 'population': 51, 'language': 'Korean', 'currency': 'Korean won'}

# %% [markdown]
# # 4. LCEL을 활용한 렝체인 생성하기
# ## 1) 문자열 출력 파서 사용
# - invoke  부르다

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
llm = ChatOllama(model="llama3.2:1b", 
                 temperature=0) # 일관된 답변
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template = "What is the capital of {country}. Return the name of the city only",
    input_variables = ["country"]
)
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(prompt_template.invoke({"country":"Korea"})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) LCEL을 사용한 간단한 체인 구성
# - 파이프연산자(|) 사용

# %%
# 프롬프트템플릿 -> llm -> 출력파서를 연결하는 체인 생성
capital_chain = prompt_template | llm | output_parser
# 생성된 체인 invoke
capital_chain.invoke({"country":"Korea"})
# Out:
# 'Seoul'
