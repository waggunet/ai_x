# %% [markdown]
# # 네이버 open API를 활용하여 네이버 지식인 "전주여행"과 "경주여행"을 검색 => 명사만 추출(re ?) -> 빈도분석(DataFrame)-> 빈도 시각화(워드클라우드, Text) -> Word2Vec

# %% [markdown]
# # 1. 네이버 openAPI 활용하여 검색 추출
# - 검색어, no, title, description, title + ' ' + description
