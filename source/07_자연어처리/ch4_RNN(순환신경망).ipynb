# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:86% !important;}
div.cell.code_cell.rendered{width:100%;}
div.CodeMirror {font-family:Consolas; font-size:13pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:10pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:10pt;padding:5px;}
table.dataframe{font-size:15px;
</style>
"""))
# Out:
# <style>
# div.container{width:86% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.CodeMirror {font-family:Consolas; font-size:13pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:10pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:10pt;padding:5px;}
# table.dataframe{font-size:15px;
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4. RNN(Recurrent Neural Network 순환신경망)</font>**
# # 1. 문맥을 이용하여 모델만들기

# %%
text = """경마장에 있는 말이 뛰고 있다 
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""
# text1 = "장마철이 오고 있다"

# %%
# from keras_preprocessing.text import Tokenizer
# t = Tokenizer()
# t.fit_on_texts([text, text1])
# encoded = t.texts_to_sequences([text, text1])
# print(encoded)
# print(t.word_index)

# %%
from keras_preprocessing.text import Tokenizer
t = Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다','말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5], [1]]
# [8, 1, 11]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는','경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i:시작index
        for j in range(i+2, len(encoded)+1): # j:끝나는 index바로 뒤
            sequences.append(encoded[i:j])
# print(sequences)
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]
# 6

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                # padding='post',
                                padding='pre')
padded_sequences.shape, type(padded_sequences)
#padded_sequences
# Out:
# ((28, 6), numpy.ndarray)

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
# X를 엠베딩 작업할 때 필요한 입력 bit 수 (단어수+1) 
input_dim = len(t.word_index)+1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding # Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model = Sequential()
model.add(Embedding(input_dim=input_dim,  # 12개로 원핫인코딩
                   output_dim=10, # 임베딩 출력의 갯수
                   input_length=X.shape[1])) # 입력(X)의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12, activation='softmax'))
print(model.summary())
# 3. 모델 학습 과정 설정
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
              metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 10)             120
#
#  simple_rnn (SimpleRNN)      (None, 32)                1376
#
#  dense (Dense)               (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.4834 - accuracy: 0.0714 - 787ms/epoch - 787ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.
- accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.4263 - accuracy: 0.8929 - 998us/epoch - 998us/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.4237 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.4211 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.4185 - accuracy: 0.8929 - 13ms/epoch - 13ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.4160 - accuracy: 0.8929 - 1ms/epoch - 1ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.4135 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.4110 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.4085 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.4061 - accuracy: 0.8929 - 1ms/epoch - 1ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.4037 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.4013 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3990 - accuracy: 0.8929 - 15ms/epoch - 15ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3966 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3943 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3921 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3898 - accuracy: 0.8929 - 16ms/epoch - 16ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3876 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3854 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3832 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3811 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3790 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3769 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3748 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3727 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3707 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3687 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3667 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3648 - accuracy: 0.8929 - 17ms/epoch - 17ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3628 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3609 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3590 - accuracy: 0.8929 - 13ms/epoch - 13ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3572 - accuracy: 0.8929 - 1ms/epoch - 1ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3553 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3535 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3517 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3499 - accuracy: 0.8929 - 197us/epoch - 197us/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3482 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3464 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3447 - accuracy: 0.8929 - 15ms/epoch - 15ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3430 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3414 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3397 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3381 - accuracy: 0.8929 - 16ms/epoch - 16ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3365 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3349 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3333 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3318 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3302 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3287 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3272 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3258 - accuracy: 0.8929 - 17ms/epoch - 17ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3243 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3229 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3215 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3187 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3173 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3160 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.3146 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.3133 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.3120 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.3108 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.3095 - accuracy: 0.8929 - 1ms/epoch - 1ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.3083 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.3070 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.3058 - accuracy: 0.8929 - 15ms/epoch - 15ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.3046 - accuracy: 0.8929 - 658us/epoch - 658us/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.3034 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.3023 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.3011 - accuracy: 0.8929 - 15ms/epoch - 15ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.3000 - accuracy: 0.8929 - 212us/epoch - 212us/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2989 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2978 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2967 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2956 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2946 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2935 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2925 - accuracy: 0.8929 - 2ms/epoch - 2ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2915 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2905 - accuracy: 0.8929 - 0s/epoch - 0s/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2895 - accuracy: 0.8929 - 0s/epoch - 0s/step

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %%
# 모델 사용하기 (경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
print('입력데이터 :', input_data)
result = model.predict(input_data, verbose=0).argmax()
word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :가는 말이
# 입력데이터 : [[0 0 0 8 1]]
# 예측된 단어 : 고와야

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음 문맥 예측해 보기

# %%
# "경마장에" 이후에 올 단어 3개 예측 -> 경마장에 있는 말이 뛰고
def sentence_generation(current_word, n):
    # print('입력된 단어 :', current_word)
    for i in range(1, n+1):
        encoded = t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' ' + word
#         print("{}번째 생성 문맥 {} ({}{})".format(i,
#                                            current_word,
#                                            encoded,
#                                            result) )
    return current_word
sentence_generation('경마장에', 3)
# Out:
# '경마장에 있는 말이 뛰고'

# %%
sentence_generation('가는', 5)
# Out:
# '가는 말이 고와야 오는 말이 곱다'
